# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Bubble Plots**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will focus on visualizing data.
#
# The dataset will be directly loaded into pandas for analysis and visualization.
#
# You will use various visualization techniques to explore the data and uncover key trends.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two data features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# #### Setup: Working with the Database
# **Install and import the needed libraries**

# %%
# !pip install pandas 
# !pip install matplotlib

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Download and connect to the database file containing survey data.**

# %% [markdown]
# To start, download and load the dataset into a `pandas` DataFrame.

# %%
# Step 1: Download the dataset
#!wget -O survey-data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv

# Load the data
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv")

# Display the first few rows of the data to understand its structure
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# ### Task 1: Exploring Data Distributions Using Bubble Plots

# %% [markdown]
# #### 1. Bubble Plot for Age vs. Frequency of Participation

# %% [markdown]
# - Visualize the relationship between respondents’ age and their participation frequency (`SOPartFreq`) using a bubble plot.
#
# - Use the size of the bubbles to represent their job satisfaction (`JobSat`).

# %%
##Write your code here
plt.figure(figsize=(15,6))
sns.scatterplot(data=df, x='Age', y='SOPartFreq', size='JobSat', sizes=(10,200), alpha= 0.3)
plt.xlabel('Age')
plt.ylabel('Participation Frequency')
plt.title('Bubble plot for Age vs. Frequency of Participation')
plt.legend(bbox_to_acnhor=(1.05, 1), loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       5 plt.ylabel('Participation Frequency')
#       6 plt.title('Bubble plot for Age vs. Frequency of Participation')
# ----> 7 plt.legend(bbox_to_acnhor=(1.05, 1), loc='upper left')
#       8 plt.show()
#
# File c:\Users\danie\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3619, in legend(*args, **kwargs)
#    3617 @_copy_docstring_and_deprecators(Axes.legend)
#    3618 def legend(*args, **kwargs) -> Legend:
# -> 3619     return gca().legend(*args, **kwargs)
#
# File c:\Users\danie\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:337, in Axes.legend(self, *args, **kwargs)
#     220 """
#     221 Place a legend on the Axes.
#     222
#    (...)
#     334 .. plot:: gallery/text_labels_and_annotations/legend.py
#     335 """
# ...

# %% [markdown]
# #### 2. Bubble Plot for Compensation vs. Job Satisfaction

# %% [markdown]
# -Visualize the relationship between yearly compensation (`ConvertedCompYearly`) and job satisfaction (`JobSat`).
#
# - Use the size of the bubbles to represent respondents’ age.

# %%
##Write your code here
plt.figure(figsize=(15,6))
sns.scatterplot(data=df, x='ConvertedCompYearly', y= 'JobSat', hue='Age', size='Age', sizes =(10,200), alpha=0.5)
plt.xlabel('Yearly Compensation')
plt.ylabel('Job Satisfaction')
plt.title('Bubble plot for Compensation vs. Job Satisfaction')
plt.legend(bbox_to_anchor=(1.05,1), loc='upper left')
plt.show()

# %% [markdown]
# ### Task 2: Analyzing Relationships Using Bubble Plots

# %% [markdown]
# #### 1. Bubble Plot of Technology Preferences by Age
#
# - Visualize the popularity of programming languages respondents have worked with (`LanguageHaveWorkedWith`) across age groups.
#
# - Use bubble size to represent the frequency of each language.

# %%
##Write your code here
df_language = df[['Age', 'LanguageHaveWorkedWith']].dropna()
df_language['Language'] = df_language['LanguageHaveWorkedWith'].str.split(';')
df_language = df_language.explode('Language')
df_language
# Out:
#                    Age                             LanguageHaveWorkedWith  \
# 1      35-44 years old  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 1      35-44 years old  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 1      35-44 years old  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 1      35-44 years old  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 1      35-44 years old  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# ...                ...                                                ...
# 65436  18-24 years old   C;HTML/CSS;Java;JavaScript;PHP;Python;TypeScript
# 65436  18-24 years old   C;HTML/CSS;Java;JavaScript;PHP;Python;TypeScript
# 65436  18-24 years old   C;HTML/CSS;Java;JavaScript;PHP;Python;TypeScript
# 65436  18-24 years old   C;HTML/CSS;Java;JavaScript;PHP;Python;TypeScript
# 65436  18-24 years old   C;HTML/CSS;Java;JavaScript;PHP;Python;TypeScript
#
#                       Language
# 1      Bash/Shell (all shells)
# ...

# %%
df_language_counts = df_language.groupby(['Age', 'Language']).size().reset_index(name='Count')

# %%
plt.figure(figsize = (15, 15))
sns.scatterplot(data = df_language_counts, x ='Age', y ='Language', size = 'Count', sizes = (10, 1000), hue = 'Language', legend = False, alpha = 0.3)
plt.title('Bubble Plot of Technology Preferences by Age (Size by Frequency)', fontsize = 16)
plt.show()

# %% [markdown]
# #### 2. Bubble Plot for Preferred Databases vs. Job Satisfaction
#
# - Explore the relationship between preferred databases (`DatabaseWantToWorkWith`) and job satisfaction.
#
# - Use bubble size to indicate the number of respondents for each database.

# %%
##Write your code here
df_data = df[['DatabaseWantToWorkWith', 'JobSat']].dropna()
df_data['Database'] = df_data['DatabaseWantToWorkWith'].str.split(';')
df_data = df_data.explode('Database')
df_data
# Out:
#                                   DatabaseWantToWorkWith  JobSat  \
# 10               Elasticsearch;MongoDB;PostgreSQL;SQLite     8.0
# 10               Elasticsearch;MongoDB;PostgreSQL;SQLite     8.0
# 10               Elasticsearch;MongoDB;PostgreSQL;SQLite     8.0
# 10               Elasticsearch;MongoDB;PostgreSQL;SQLite     8.0
# 12                                                 MySQL     8.0
# ...                                                  ...     ...
# 65351  Cassandra;Firebase Realtime Database;MariaDB;M...     8.0
# 65351  Cassandra;Firebase Realtime Database;MariaDB;M...     8.0
# 65351  Cassandra;Firebase Realtime Database;MariaDB;M...     8.0
# 65351  Cassandra;Firebase Realtime Database;MariaDB;M...     8.0
# 65351  Cassandra;Firebase Realtime Database;MariaDB;M...     8.0
#
#                Database
# 10        Elasticsearch
# 10              MongoDB
# 10           PostgreSQL
# 10               SQLite
# 12                MySQL
# ...                 ...
# ...

# %%
data_counts = df_data.groupby(['Database', 'JobSat']).size().reset_index(name = 'Count')

# %%
plt.figure(figsize = (12, 12))
sns.scatterplot(data = data_counts, x = 'JobSat', y = 'Database', size = 'Count', sizes = (20, 1000), hue = 'Count', legend = False, alpha = 0.5, palette='viridis')
plt.title('Bubble Plot for Preferred Databases vs. Job Satisfaction', fontsize = 16)
plt.legend(bbox_to_anchor=(1.05, 1),loc='upper left')
plt.show()
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_8816\3211024731.py:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(bbox_to_anchor=(1.05, 1),loc='upper left')

# %% [markdown]
# ### Task 3: Comparing Data Using Bubble Plots

# %% [markdown]
# #### 1. Bubble Plot for Compensation Across Developer Roles
#
# - Visualize compensation (`ConvertedCompYearly`) across different developer roles (`DevType`).
#
# - Use bubble size to represent job satisfaction.

# %%
##Write your code here
plt.figure(figsize=(15,6))
sns.scatterplot(data=df, x='ConvertedCompYearly', y='DevType', size='JobSat', sizes=(10,200), hue='JobSat', palette='viridis', alpha=0.5)
plt.xlabel('Yearly Compensation')
plt.ylabel('Developer Roles')
plt.title('Bubble plot for Compensation Across Developer Roles')
plt.show()

# %% [markdown]
# #### 2. Bubble Plot for Collaboration Tools by Age
#
# - Visualize the relationship between the collaboration tools used (`NEWCollabToolsHaveWorkedWith`) and age groups.
#
# - Use bubble size to represent the frequency of tool usage.

# %%
##Write your code here
df_group = df[['Age', 'NEWCollabToolsHaveWorkedWith']].dropna()
df_group['Tool'] = df['NEWCollabToolsHaveWorkedWith'].str.split(';')
df_group = df_group.explode('Tool')
df_count = df_group.groupby(['Age', 'Tool']).size().reset_index(name='Frequency')
df_count
# Out:
#                     Age                Tool  Frequency
# 0       18-24 years old      Android Studio       2663
# 1       18-24 years old              BBEdit         35
# 2       18-24 years old               CLion       1168
# 3       18-24 years old        Code::Blocks        531
# 4       18-24 years old            DataGrip        709
# ..                  ...                 ...        ...
# 274  Under 18 years old                 Vim        438
# 275  Under 18 years old       Visual Studio        780
# 276  Under 18 years old  Visual Studio Code       1808
# 277  Under 18 years old            WebStorm        155
# 278  Under 18 years old               Xcode        147
#
# [279 rows x 3 columns]

# %%
plt.figure(figsize=(15, 15))
sns.scatterplot(data = df_count, x = 'Age', y = 'Tool', size = 'Frequency', sizes=(20, 1000), hue = 'Frequency', alpha = 0.5, palette = 'Spectral')
plt.title('Bubble Plot for Collaboration Tools by Age', fontsize = 18)
plt.legend(bbox_to_anchor = (1.05, 1), loc = 'upper left')
plt.show()

# %% [markdown]
# ### Task 4: Visualizing Technology Trends Using Bubble Plots

# %% [markdown]
# #### 1. Bubble Plot for Preferred Web Frameworks vs. Job Satisfaction
#
# - Explore the relationship between preferred web frameworks (`WebframeWantToWorkWith`) and job satisfaction.
#
# - Use bubble size to represent the number of respondents.

# %%
##Write your code here
df_web = df[['WebframeWantToWorkWith', 'JobSat']].dropna()
df_web['Framework'] = df_web['WebframeWantToWorkWith'].str.split(';')
df_web = df_web.explode('Framework')
df_web
# Out:
#                                   WebframeWantToWorkWith  JobSat  \
# 10                    Django;Node.js;React;Ruby on Rails     8.0
# 10                    Django;Node.js;React;Ruby on Rails     8.0
# 10                    Django;Node.js;React;Ruby on Rails     8.0
# 10                    Django;Node.js;React;Ruby on Rails     8.0
# 15                                                Blazor     5.0
# ...                                                  ...     ...
# 65351  Django;Express;Laravel;NestJS;Next.js;Node.js;...     8.0
# 65351  Django;Express;Laravel;NestJS;Next.js;Node.js;...     8.0
# 65351  Django;Express;Laravel;NestJS;Next.js;Node.js;...     8.0
# 65351  Django;Express;Laravel;NestJS;Next.js;Node.js;...     8.0
# 65351  Django;Express;Laravel;NestJS;Next.js;Node.js;...     8.0
#
#            Framework
# 10            Django
# 10           Node.js
# 10             React
# 10     Ruby on Rails
# 15            Blazor
# ...              ...
# 65351          React
# ...

# %%
df_web_count = df_web.groupby(['Framework', 'JobSat']).size().reset_index(name='Respondents')

# %%
plt.figure(figsize=(15, 15))
sns.scatterplot(data = df_web_count, x = 'JobSat', y = 'Framework', size = 'Respondents', sizes=(20, 1000), hue = 'Respondents', alpha = 0.5, palette = 'viridis')
plt.title('Bubble Plot for Preferred Web Frameworks vs. Job Satisfaction', fontsize = 18)
plt.legend(bbox_to_anchor = (1.05, 1), loc = 'upper left')
plt.show()

# %% [markdown]
# #### 2. Bubble Plot for Admired Technologies Across Countries
#
# - Visualize the distribution of admired technologies (`LanguageAdmired`) across different countries (`Country`).
#
# - Use bubble size to represent the frequency of admiration.

# %%
##Write your code here
top = df['Country'].value_counts().nlargest(10).index
df_top = df[df['Country'].isin(top)]

# %%
df_adm = df_top[['LanguageAdmired', 'Country']].dropna()
df_adm['Language'] = df_adm['LanguageAdmired'].str.split(';')
df_adm = df_adm.explode('Language')
df_adm_count = df_adm.groupby(['Country','Language']).size().reset_index(name='Frequency')
df_adm_count
# Out:
#                       Country                 Language  Frequency
# 0                      Brazil                      Ada          2
# 1                      Brazil                     Apex         12
# 2                      Brazil                 Assembly         18
# 3                      Brazil  Bash/Shell (all shells)        269
# 4                      Brazil                        C        102
# ..                        ...                      ...        ...
# 480  United States of America               TypeScript       2767
# 481  United States of America                      VBA        112
# 482  United States of America      Visual Basic (.Net)        127
# 483  United States of America                   Zephyr         18
# 484  United States of America                      Zig        116
#
# [485 rows x 3 columns]

# %%
plt.figure(figsize=(14, 12))
sns.scatterplot(data = df_adm_count, x = 'Country', y = 'Language', size = 'Frequency', sizes = (20, 1000), hue = 'Frequency', palette = 'viridis', alpha = 0.5)
plt.title('Bubble Plot for Admired Technologies Across Countries (Size by Frequency)', fontsize = 16)
plt.xticks(rotation=45, ha = 'right')
plt.legend(bbox_to_anchor = (1.05, 1), loc = 'upper left')
plt.show()

# %% [markdown]
# ## Final Step: Review

# %% [markdown]
# After completing the lab, you will have extensively used bubble plots to gain insights into developer community preferences, demographics, compensation trends, and job satisfaction.

# %% [markdown]
# ## Summary

# %% [markdown]
# After completing this lab, you will be able to:
#
# - Create and interpret bubble plots to analyze relationships and compositions within datasets.
#
# - Use bubble plots to explore developer preferences, compensation trends, and satisfaction levels.
#
# - Apply bubble plots to visualize complex relationships involving multiple dimensions effectively.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# - Rav Ahuja
# - Lakshmi Holla
# - Malika

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-10-29|1.2|Madhusudhan Moole|Updated lab|
# |2024-10-16|1.1|Madhusudhan Moole|Updated lab|
# |2024-10-15|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
